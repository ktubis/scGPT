# %%
import opendelta
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import opendelta
#
# File ~/anaconda3/envs/delta/lib/python3.10/site-packages/opendelta/__init__.py:14
#      12 from .utils import logging
#      13 from .utils.saving_loading_utils import SaveLoadMixin
# ---> 14 from .basemodel import DeltaBase
#      15 from .auto_delta import AutoDeltaConfig, AutoDeltaModel
#      16 from .utils.structure_mapping import CommonStructureMap
#
# File ~/anaconda3/envs/delta/lib/python3.10/site-packages/opendelta/basemodel.py:20
#      18 from opendelta.utils.structure_mapping import transform
#      19 from transformers.file_utils import PushToHubMixin
# ---> 20 from transformers.deepspeed import deepspeed_config, is_deepspeed_zero3_enabled
#      21 from opendelta import SaveLoadMixin
#      22 from opendelta import logging
#
# ...

# %%
import torch
print(torch.__version__)
# Out:
# 2.2.0

# %%
with open("logs/pretrained_model.txt", 'r') as f:
    lines = f.readlines()

# %%
predictions = np.array(lines[1])

# %%
labels = np.array(lines[3])

# %%
predictions
# Out:
# array(' [4, 8, 4, 4, 4, 4, 4, 8, 4, 4, 4, 4, 4, 4, 4, 4, 8, 4, 4, 4, 4, 4, 4, 4, 8, 4, 4, 4, 8, 4, 4, 8, 4, 8, 8, 8, 8, 8, 4, 4, 8, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 8, 8, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 8, 4, 8, 4, 4, 4, 4, 4, 8, 4, 8, 8, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 8, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 8, 4, 4, 4, 4, 8, 8, 8, 4, 4, 4, 8, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 8, 8, 8, 4, 4, 4, 8, 4, 8, 4, 4, 4, 4, 4, 4, 4, 8, 4, 4, 4, 4, 4, 4, 4, 4, 4, 8, 4, 4, 4, 4, 8, 4, 8, 4, 4, 4, 4, 4, 4, 4, 4, 4, 8, 4, 4, 4, 8, 8, 8, 4, 8, 8, 8, 4, 4, 4, 4, 8, 4, 4, 4, 4, 4, 4, 4, 4, 4, 8, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 8, 4, 4, 8, 4, 4, 4, 8, 4, 4, 4, 4, 4, 4, 4, 8, 4, 4, 4, 4, 4, 4, 4, 4, 4, 8, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 8, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 8, 4, 8, 4, 4, 4, 8, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 8, 4, 4, 4, 4,
# ...
