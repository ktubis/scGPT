# %%
import opendelta
import json

# %%
delta_configs = {

    "adapter_default": {
        "delta_type":"adapter", 
        "modified_modules":[
            "linear2"
        ],
    },
    "adapter12": {
        "delta_type":"adapter", 
        "modified_modules":[
            "linear1",
        ],
        "bottleneck_dim": 12,
    },
    "adapter48": {
        "delta_type":"adapter", 
        "modified_modules":[
            "linear1",
        ],
        "bottleneck_dim": 48,
    },
}

# %%
delta_configs
# Out:
# {'adapter_default': {'delta_type': 'adapter', 'modified_modules': ['linear2']}}

# %%
with open("delta_model_configs/delta_configs.json", "w") as f:
    json.dump(delta_configs, f, indent=4)
